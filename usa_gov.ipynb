# %%
import pandasplot(arange(10))

# %%
import pandasplot(arange(100))

# %%
plot(arange(50))

# %%
a=rand(100)plot(a)

# %%
#usagov_bitly_data_path='F:\syn\git\pydata-book\ch02\usagov_bitly_data2012-03-16-1331923249.txt'usagov_bitly_data_path='E:\git\pydata-book\ch02\usagov_bitly_data2012-03-16-1331923249.txt'f=open(usagov_bitly_data_path)f.readline()
# Out:
# '{ "a": "Mozilla\\/5.0 (Windows NT 6.1; WOW64) AppleWebKit\\/535.11 (KHTML, like Gecko) Chrome\\/17.0.963.78 Safari\\/535.11", "c": "US", "nk": 1, "tz": "America\\/New_York", "gr": "MA", "g": "A6qOVH", "h": "wfLQtf", "l": "orofrog", "al": "en-US,en;q=0.8", "hh": "1.usa.gov", "r": "http:\\/\\/www.facebook.com\\/l\\/7AQEFzjSi\\/1.usa.gov\\/wfLQtf", "u": "http:\\/\\/www.ncbi.nlm.nih.gov\\/pubmed\\/22415991", "t": 1331923247, "hc": 1331822918, "cy": "Danvers", "ll": [ 42.576698, -70.954903 ] }\n'
# '{ "a": "Mozilla\\/5.0 (Windows NT 6.1; WOW64) AppleWebKit\\/535.11 (KHTML, like Gecko) Chrome\\/17.0.963.78 Safari\\/535.11", "c": "US", "nk": 1, "tz": "America\\/New_York", "gr": "MA", "g": "A6qOVH", "h": "wfLQtf", "l": "orofrog", "al": "en-US,en;q=0.8", "hh": "1.usa.gov", "r": "http:\\/\\/www.facebook.com\\/l\\/7AQEFzjSi\\/1.usa.gov\\/wfLQtf", "u": "http:\\/\\/www.ncbi.nlm.nih.gov\\/pubmed\\/22415991", "t": 1331923247, "hc": 1331822918, "cy": "Danvers", "ll": [ 42.576698, -70.954903 ] }\n'

# %%
import jsonrecords=[json.loads(line) for line in f]

# %%
records[0]
# Out:
# {u'a': u'GoogleMaps/RochesterNY', u'c': u'US', u'cy': u'Provo', u'g': u'mwszkS', u'gr': u'UT', u'h': u'mwszkS', u'hc': 1308262393, u'hh': u'j.mp', u'l': u'bitly', u'll': [40.218102, -111.613297], u'nk': 0, u'r': u'http://www.AwareMap.com/', u't': 1331923249, u'tz': u'America/Denver', u'u': u'http://www.monroecounty.gov/etc/911/rss.php'}
# {u'a': u'GoogleMaps/RochesterNY', u'c': u'US', u'cy': u'Provo', u'g': u'mwszkS', u'gr': u'UT', u'h': u'mwszkS', u'hc': 1308262393, u'hh': u'j.mp', u'l': u'bitly', u'll': [40.218102, -111.613297], u'nk': 0, u'r': u'http://www.AwareMap.com/', u't': 1331923249, u'tz': u'America/Denver', u'u': u'http://www.monroecounty.gov/etc/911/rss.php'}

# %%
records[0]['tz']
# Out:
# u'America/Denver'
# u'America/Denver'

# %%
print records[0]['tz']
# Out:
# America/Denver
# America/Denver

# %%
print records[0]['nk']
# Out:
# 0
# 0

# %%
time_zones=[rec['tz'] for rec in records if 'tz' in rec]

# %%
time_zones[:10]
# Out:
# [u'America/Denver', u'America/New_York', u'America/Sao_Paulo', u'America/New_York', u'America/New_York', u'Europe/Warsaw', u'', u'', u'', u'America/Los_Angeles']
# [u'America/Denver', u'America/New_York', u'America/Sao_Paulo', u'America/New_York', u'America/New_York', u'Europe/Warsaw', u'', u'', u'', u'America/Los_Angeles']

# %%
len(time_zones)
# Out:
# 3439
# 3439

# %%
records[:2]
# Out:
# [{u'a': u'GoogleMaps/RochesterNY',  u'c': u'US',  u'cy': u'Provo',  u'g': u'mwszkS',  u'gr': u'UT',  u'h': u'mwszkS',  u'hc': 1308262393,  u'hh': u'j.mp',  u'l': u'bitly',  u'll': [40.218102, -111.613297],  u'nk': 0,  u'r': u'http://www.AwareMap.com/',  u't': 1331923249,  u'tz': u'America/Denver',  u'u': u'http://www.monroecounty.gov/etc/911/rss.php'}, {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; InfoPath.3)',  u'al': u'en-US',  u'c': u'US',  u'cy': u'Washington',  u'g': u'xxr3Qb',  u'gr': u'DC',  u'h': u'xxr3Qb',  u'hc': 1331919941,  u'hh': u'1.usa.gov',  u'l': u'bitly',  u'll': [38.9007, -77.043098],  u'nk': 1,  u'r': u'http://t.co/03elZC4Q',  u't': 1331923250,  u'tz': u'America/New_York',  u'u': u'http://boxer.senate.gov/en/press/releases/031612.cfm'}]
# ...

# %%
def get_counts(sequence):    counts={}    for x in sequence:        if x in counts:            counts[x] += 1        else:            counts[x] = 1    return counts

# %%
get_counts(time_zones)['Africa/Cairo']
# Out:
# 3
# 3

# %%
from collections import defaultdictdef get_counts2(sequence):    counts = defaultdict(int) #所有的值均会初始化为0    for x in sequence:        counts[x] += 1    return counts

# %%
counts = get_counts2(time_zones)

# %%
counts['America/New_York']
# Out:
# 1250
# 1250

# %%
len(time_zones)
# Out:
# 3439
# 3439

# %%
def top_counts(count_dict, n=10):    value_key_pairs = [(count, tz) for tz,count in count_dict.items()]    value_key_pairs.sort()    return value_key_pairs[-n:]

# %%
top_counts(counts)
# Out:
# [(33, u'America/Sao_Paulo'), (35, u'Europe/Madrid'), (36, u'Pacific/Honolulu'), (37, u'Asia/Tokyo'), (74, u'Europe/London'), (191, u'America/Denver'), (382, u'America/Los_Angeles'), (400, u'America/Chicago'), (521, u''), (1250, u'America/New_York')]
# [(33, u'America/Sao_Paulo'), (35, u'Europe/Madrid'), (36, u'Pacific/Honolulu'), (37, u'Asia/Tokyo'), (74, u'Europe/London'), (191, u'America/Denver'), (382, u'America/Los_Angeles'), (400, u'America/Chicago'), (521, u''), (1250, u'America/New_York')]

# %%
from collections import Countercounts2=Counter(time_zones)counts2.most_common(10)
# Out:
# [(u'America/New_York', 1250), (u'', 521), (u'America/Chicago', 400), (u'America/Los_Angeles', 382), (u'America/Denver', 191), (u'Europe/London', 74), (u'Asia/Tokyo', 37), (u'Pacific/Honolulu', 36), (u'Europe/Madrid', 35), (u'America/Sao_Paulo', 33)]
# [(u'America/New_York', 1250), (u'', 521), (u'America/Chicago', 400), (u'America/Los_Angeles', 382), (u'America/Denver', 191), (u'Europe/London', 74), (u'Asia/Tokyo', 37), (u'Pacific/Honolulu', 36), (u'Europe/Madrid', 35), (u'America/Sao_Paulo', 33)]

# %%
from pandas import DataFrame, Seriesimport pandas as pdimport numpy as npframe = DataFrame(records)frame
# Out:
# <class 'pandas.core.frame.DataFrame'>Int64Index: 3559 entries, 0 to 3558Data columns:_heartbeat_    120  non-null valuesa              3439  non-null valuesal             3093  non-null valuesc              2918  non-null valuescy             2918  non-null valuesg              3439  non-null valuesgr             2918  non-null valuesh              3439  non-null valueshc             3439  non-null valueshh             3439  non-null valueskw             93  non-null valuesl              3439  non-null valuesll             2918  non-null valuesnk             3439  non-null valuesr              3439  non-null valuest              3439  non-null valuestz             3439  non-null valuesu              3439  non-null valuesdtypes: float64(4), object(14)
# ...

# %%
frame['tz'][:10]
# Out:
# 0         America/Denver1       America/New_York2      America/Sao_Paulo3       America/New_York4       America/New_York5          Europe/Warsaw6                       7                       8                       9    America/Los_AngelesName: tz
# 0         America/Denver1       America/New_York2      America/Sao_Paulo3       America/New_York4       America/New_York5          Europe/Warsaw6                       7                       8                       9    America/Los_AngelesName: tz

# %%
tz_counts = frame['tz'].value_counts()

# %%
tz_counts[:10]
# Out:
# America/New_York       1250                        521America/Chicago         400America/Los_Angeles     382America/Denver          191Europe/London            74Asia/Tokyo               37Pacific/Honolulu         36Europe/Madrid            35America/Sao_Paulo        33
# America/New_York       1250                        521America/Chicago         400America/Los_Angeles     382America/Denver          191Europe/London            74Asia/Tokyo               37Pacific/Honolulu         36Europe/Madrid            35America/Sao_Paulo        33

# %%
clean_tz = frame['tz'].fillna('Missing')clean_tz[clean_tz == ''] = 'Unknown'tz_counts = clean_tz.value_counts()tz_counts[:10]
# Out:
# America/New_York       1250Unknown                 521America/Chicago         400America/Los_Angeles     382America/Denver          191Missing                 120Europe/London            74Asia/Tokyo               37Pacific/Honolulu         36Europe/Madrid            35
# America/New_York       1250Unknown                 521America/Chicago         400America/Los_Angeles     382America/Denver          191Missing                 120Europe/London            74Asia/Tokyo               37Pacific/Honolulu         36Europe/Madrid            35

# %%
tz_counts[:10].plot(kind='barh', rot=0)

# %%
frame['a'][1]
# Out:
# u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; InfoPath.3)'
# u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; InfoPath.3)'

# %%
frame['a'][50]
# Out:
# u'Mozilla/5.0 (Linux; U; Android 2.2.2; en-us; LG-P925/V10e Build/FRG83G) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1'
# u'Mozilla/5.0 (Linux; U; Android 2.2.2; en-us; LG-P925/V10e Build/FRG83G) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1'

# %%
frame['a'][51]
# Out:
# u'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11'
# u'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11'

# %%
results = Series([x.split()[0] for x in frame.a.dropna()])results[:5]
# Out:
# 0    GoogleMaps/RochesterNY1               Mozilla/4.02               Mozilla/5.03               Mozilla/5.04               Mozilla/5.0
# 0    GoogleMaps/RochesterNY1               Mozilla/4.02               Mozilla/5.03               Mozilla/5.04               Mozilla/5.0

# %%
results.value_counts()[:8]
# Out:
# Mozilla/5.0                 2593Mozilla/4.0                  601GoogleMaps/RochesterNY       121Opera/9.80                    34TEST_INTERNET_AGENT           24GoogleProducer                21Mozilla/6.0                    5BlackBerry8520/5.0.0.681       4
# Mozilla/5.0                 2593Mozilla/4.0                  601GoogleMaps/RochesterNY       121Opera/9.80                    34TEST_INTERNET_AGENT           24GoogleProducer                21Mozilla/6.0                    5BlackBerry8520/5.0.0.681       4

# %%
cframe = frame[frame.a.notnull()]operting_system = np.where(cframe['a'].str.contains('Windows'), 'Windows', 'Not Windows')

# %%
operting_system[:5]
# Out:
# 0    Not Windows1        Windows2    Not Windows3        Windows4        WindowsName: a
# 0    Not Windows1        Windows2    Not Windows3        Windows4        WindowsName: a

# %%
by_tz_os = cframe.groupby(['tz', operting_system])

# %%
agg_counts = by_tz_os.size().unstack().fillna(0)

# %%
agg_counts[:10]
# Out:
# a                               Not Windows  Windowstz                                                                                          245      276Africa/Cairo                              0        3Africa/Casablanca                         0        1Africa/Ceuta                              0        2Africa/Johannesburg                       0        1Africa/Lusaka                             0        1America/Anchorage                         4        1America/Argentina/Buenos_Aires            1        0America/Argentina/Cordoba                 0        1America/Argentina/Mendoza                 0        1

# %%
indexer = agg_counts.sum(1).argsort()indexer[:10]
# Out:
# tz                                  24Africa/Cairo                      20Africa/Casablanca                 21Africa/Ceuta                      92Africa/Johannesburg               87Africa/Lusaka                     53America/Anchorage                 54America/Argentina/Buenos_Aires    57America/Argentina/Cordoba         26America/Argentina/Mendoza         55

# %%
count_subset = agg_counts.take(indexer)[-10:]count_subset
# Out:
# a                    Not Windows  Windowstz                                       America/Sao_Paulo             13       20Europe/Madrid                 16       19Pacific/Honolulu               0       36Asia/Tokyo                     2       35Europe/London                 43       31America/Denver               132       59America/Los_Angeles          130      252America/Chicago              115      285                             245      276America/New_York             339      911

# %%
count_subset.plot(kind='barh', stacked=True)

# %%
normed_subset = count_subset.div(count_subset.sum(1), axis=0)normed_subset.plot(kind='barh', stacked=True)
